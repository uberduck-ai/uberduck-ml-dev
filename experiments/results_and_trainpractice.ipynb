# %%
import tensorflow as tf
import tensorboard

# %%
from tensorflow.python.summary.summary_iterator import summary_iterator

# %%
si = summary_iterator('/mnt/disks/uberduck-experiments-v0/uberduck-ml-dev/experiments/logs/events.out.tfevents.1632116346.uberduck-sam-t4-west2c')

#

# %%
#checkpoint

# %%
list(enumerate(si))
for e in si:
    for v in e.summary.value:
        if v.tag == 'loss' or v.tag == 'accuracy':
            print(v.simple_value)
# Out:
# [(0,
#   wall_time: 1632116346.539003
#   file_version: "brain.Event:2"),
#  (1,
#   wall_time: 1632116356.2859178
#   summary {
#     value {
#       tag: "training.loss"
#       simple_value: 41.56840896606445
#     }
#   }),
#  (2,
#   wall_time: 1632116356.2879424
#   summary {
#     value {
#       tag: "grad.norm"
#       simple_value: inf
#     }
#   }),
#  (3,
#   wall_time: 1632116356.2880597
#   summary {
#     value {
#       tag: "learning.rate"
#       simple_value: 0.0010000000474974513
#     }
#   }),
#  (4,
#   wall_time: 1632116356.288132
#   summary {
#     value {
#       tag: "duration"
#       simple_value: 3.5802018642425537
#     }
#   }),
#  (5,
#   wall_time: 1632116401.1919203
#   summary {
#     value {
#       tag: "validation.loss"
#       simple_value: 36.302894592285156
#     }
#   }),
#  (6,
#   wall_time: 1632116401.2057188
#   summary {
#     value {
#       tag: "embedding/weight"
#       histo {
#         min: -0.0927734375
# ...

# %%
from train import train

# %%
n_speakers = 1
import text
from text.symbols import symbols
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_7540/3236518781.py in <module>
#       1 n_speakers = 1
# ----> 2 import text
#       3 from text.symbols import symbols
#
# ModuleNotFoundError: No module named 'text'

# %%
    hparams = tf.contrib.training.HParams(#hp.HParam(#tf.contrib.training.HParams(#tf.plugins.training.HParamas(#tf.contrib.training.HParams(
        ################################
        # Experiment Parameters        #
        ################################
        epochs=50000,
        iters_per_checkpoint=500,
        seed=1234,
        dynamic_loss_scaling=False,
        fp16_run=False,
        distributed_run=False,
        dist_backend="nccl",
        dist_url="tcp://localhost:54321",
        cudnn_enabled=True,
        cudnn_benchmark=False,
        ignore_layers=['speaker_embedding.weight'],

        ################################
        # Data Parameters             #
        ################################
        #training_files='filelists/ljs_audiopaths_text_sid_train_filelist.txt',
        training_files='/Users/samsonkoelle/Downloads/eminem_14/train_multispeaker.txt',
        validation_files='/Users/samsonkoelle/Downloads/eminem_14/val_multispeaker.txt',
        text_cleaners=['english_cleaners'],
        p_arpabet=1.0,
        cmudict_path="data/cmu_dictionary",

        ################################
        # Audio Parameters             #
        ################################
        max_wav_value=32768.0,
        sampling_rate=22050,
        filter_length=1024,
        hop_length=256,
        win_length=1024,
        n_mel_channels=80,
        mel_fmin=0.0,
        mel_fmax=8000.0,
        f0_min=80,
        f0_max=880,
        harm_thresh=0.25,

        ################################
        # Model Parameters             #
        ################################
        n_symbols=len(symbols),
        symbols_embedding_dim=512,

        # Encoder parameters
        encoder_kernel_size=5,
        encoder_n_convolutions=3,
        encoder_embedding_dim=512,

        # Decoder parameters
        n_frames_per_step=1,  # currently only 1 is supported
        decoder_rnn_dim=1024,
        prenet_dim=256,
        prenet_f0_n_layers=1,
        prenet_f0_dim=1,
        prenet_f0_kernel_size=1,
        prenet_rms_dim=0,
        prenet_rms_kernel_size=1,
        max_decoder_steps=1000,
        gate_threshold=0.5,
        p_attention_dropout=0.1,
        p_decoder_dropout=0.1,
        p_teacher_forcing=1.0,

        # Attention parameters
        attention_rnn_dim=1024,
        attention_dim=128,

        # Location Layer parameters
        attention_location_n_filters=32,
        attention_location_kernel_size=31,

        # Mel-post processing network parameters
        postnet_embedding_dim=512,
        postnet_kernel_size=5,
        postnet_n_convolutions=5,

        # Speaker embedding
        n_speakers=n_speakers,
        speaker_embedding_dim=128,

        # Reference encoder
        with_gst=True,
        ref_enc_filters=[32, 32, 64, 64, 128, 128],
        ref_enc_size=[3, 3],
        ref_enc_strides=[2, 2],
        ref_enc_pad=[1, 1],
        ref_enc_gru_size=128,

        # Style Token Layer
        token_embedding_size=256,
        token_num=10,
        num_heads=8,

        ################################
        # Optimization Hyperparameters #
        ################################
        use_saved_learning_rate=False,
        learning_rate=1e-6,
        learning_rate_min=1e-6,
        learning_rate_anneal=50000,
        weight_decay=0.,#1e-6,
        grad_clip_thresh=1.0,
        batch_size=2,
        mask_padding=True,  # set model's padded outputs to padded values

    )
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7540/1162430806.py in <module>
#      43     # Model Parameters             #
#      44     ################################
# ---> 45     n_symbols=len(symbols),
#      46     symbols_embedding_dim=512,
#      47
#
# NameError: name 'symbols' is not defined
